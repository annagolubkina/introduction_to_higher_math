# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
k1 = 1
k2 = 2
x = np.linspace(-10, 10, 101)
plt.plot(x, np.cos(k1 * x), '-', x, np.cos(k2 * x), '--')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
